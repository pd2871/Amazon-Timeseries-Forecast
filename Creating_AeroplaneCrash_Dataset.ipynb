# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Airplane_Crashes.csv")

# %%
data.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
data.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5246.000000  5256.000000  5246.000000
# mean     27.554518    20.068303     1.608845
# std      43.076711    33.199952    53.987827
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %%
data.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Date            0
# Time            0
# Location        0
# Operator        0
# Flight #        0
# Route           0
# Type            0
# Registration    0
# cn/In           0
# Aboard          0
# Fatalities      0
# Ground          0
# Summary         0
# dtype: int64

# %%
data.head()
# Out:
#            Date   Time               Location  \
# 208  01/19/1930  18:23  Oceanside, California
# 236  03/31/1931  10:45         Bazaar, Kansas
# 334  08/31/1934  23:42     Amazonia, Missouri
# 354  05/06/1935  03:30      Atlanta, Missouri
# 365  08/14/1935  23:45     Near Gilmer, Texas
#
#                               Operator Flight #  \
# 208                    Maddux Airlines        7
# 236  Trans Continental and Western Air      599
# 334                Rapid Air Transport        6
# 354  Trans Continental and Western Air        6
# 365                    Delta Air Lines        4
#
#                                                  Route                   Type  \
# 208                Aqua Caliente, Mexico - Los Angeles  Ford 5-AT-C Tri Motor
# 236               Kansas City - Wichita -  Los Angeles   Fokker F10A Trimotor
# 334                                 Omaha - St. Joseph      Stinson  SM-6000B
# ...

# %%
data[data['Date']=='01/19/2002']
# Out:
#             Date     Time                         Location       Operator  \
# 4838  01/19/2002  c: 9:40  Near Milford Sound, New Zealand  Air Fiordland
#
#      Flight #                     Route                 Type Registration  \
# 4838        -  Te Anau  - Milford Sound  Cessna 207 Skywagon       ZK-SEV
#
#          cn/In  Aboard  Fatalities  Ground  \
# 4838  20700204     6.0         6.0     0.0
#
#                                                 Summary
# 4838  The sightseeing plane hit a mountainside at  a...

# %%
data.drop(4838, axis=0, inplace=True)

# %%
data.head()
# Out:
#            Date   Time               Location  \
# 208  01/19/1930  18:23  Oceanside, California
# 236  03/31/1931  10:45         Bazaar, Kansas
# 334  08/31/1934  23:42     Amazonia, Missouri
# 354  05/06/1935  03:30      Atlanta, Missouri
# 365  08/14/1935  23:45     Near Gilmer, Texas
#
#                               Operator Flight #  \
# 208                    Maddux Airlines        7
# 236  Trans Continental and Western Air      599
# 334                Rapid Air Transport        6
# 354  Trans Continental and Western Air        6
# 365                    Delta Air Lines        4
#
#                                                  Route                   Type  \
# 208                Aqua Caliente, Mexico - Los Angeles  Ford 5-AT-C Tri Motor
# 236               Kansas City - Wichita -  Los Angeles   Fokker F10A Trimotor
# 334                                 Omaha - St. Joseph      Stinson  SM-6000B
# ...

# %%
data["Timestamp"] = pd.to_datetime(data['Date']+ " "+ data['Time'])

# %%
data.head()
# Out:
#            Date   Time               Location  \
# 208  01/19/1930  18:23  Oceanside, California
# 236  03/31/1931  10:45         Bazaar, Kansas
# 334  08/31/1934  23:42     Amazonia, Missouri
# 354  05/06/1935  03:30      Atlanta, Missouri
# 365  08/14/1935  23:45     Near Gilmer, Texas
#
#                               Operator Flight #  \
# 208                    Maddux Airlines        7
# 236  Trans Continental and Western Air      599
# 334                Rapid Air Transport        6
# 354  Trans Continental and Western Air        6
# 365                    Delta Air Lines        4
#
#                                                  Route                   Type  \
# 208                Aqua Caliente, Mexico - Los Angeles  Ford 5-AT-C Tri Motor
# 236               Kansas City - Wichita -  Los Angeles   Fokker F10A Trimotor
# 334                                 Omaha - St. Joseph      Stinson  SM-6000B
# ...

# %%
len(data['Location'].value_counts())
# Out:
# 849

# %%
len(data['Operator'].value_counts())
# Out:
# 527

# %%
len(data['Type'].value_counts())
# Out:
# 619

# %%
len(data['Route'].value_counts())
# Out:
# 909

# %%
data.shape
# Out:
# (943, 14)

# %%
len(data['Fatalities'].value_counts())
# Out:
# 179

# %%
data = data.reset_index()

# %%
data.head()
# Out:
#    index        Date   Time               Location  \
# 0    208  01/19/1930  18:23  Oceanside, California
# 1    236  03/31/1931  10:45         Bazaar, Kansas
# 2    334  08/31/1934  23:42     Amazonia, Missouri
# 3    354  05/06/1935  03:30      Atlanta, Missouri
# 4    365  08/14/1935  23:45     Near Gilmer, Texas
#
#                             Operator Flight #  \
# 0                    Maddux Airlines        7
# 1  Trans Continental and Western Air      599
# 2                Rapid Air Transport        6
# 3  Trans Continental and Western Air        6
# 4                    Delta Air Lines        4
#
#                                                Route                   Type  \
# 0                Aqua Caliente, Mexico - Los Angeles  Ford 5-AT-C Tri Motor
# 1               Kansas City - Wichita -  Los Angeles   Fokker F10A Trimotor
# 2                                 Omaha - St. Joseph      Stinson  SM-6000B
# ...

# %%
data['item_id'] = data['Operator']

# %%
data['timestamp'] = data['Timestamp']

# %%
data['target_value'] = data['Fatalities']

# %%
data.head()
# Out:
#    index        Date   Time               Location  \
# 0    208  01/19/1930  18:23  Oceanside, California
# 1    236  03/31/1931  10:45         Bazaar, Kansas
# 2    334  08/31/1934  23:42     Amazonia, Missouri
# 3    354  05/06/1935  03:30      Atlanta, Missouri
# 4    365  08/14/1935  23:45     Near Gilmer, Texas
#
#                             Operator Flight #  \
# 0                    Maddux Airlines        7
# 1  Trans Continental and Western Air      599
# 2                Rapid Air Transport        6
# 3  Trans Continental and Western Air        6
# 4                    Delta Air Lines        4
#
#                                                Route                   Type  \
# 0                Aqua Caliente, Mexico - Los Angeles  Ford 5-AT-C Tri Motor
# 1               Kansas City - Wichita -  Los Angeles   Fokker F10A Trimotor
# 2                                 Omaha - St. Joseph      Stinson  SM-6000B
# ...

# %%
data = data[['item_id','target_value','timestamp']]

# %%
data.head()
# Out:
#                              item_id  target_value           timestamp
# 0                    Maddux Airlines          16.0 1930-01-19 18:23:00
# 1  Trans Continental and Western Air           8.0 1931-03-31 10:45:00
# 2                Rapid Air Transport           5.0 1934-08-31 23:42:00
# 3  Trans Continental and Western Air           5.0 1935-05-06 03:30:00
# 4                    Delta Air Lines           4.0 1935-08-14 23:45:00

# %%
data.to_csv("aeroplane_crash_for_amazon_forecast.csv", index=False)
